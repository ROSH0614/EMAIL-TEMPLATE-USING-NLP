# %%
import bs4
from bs4 import BeautifulSoup as bs
import csv
import requests
import time
import pandas as pd
import urllib
import re
import pickle
import datetime

# %%
url = "https://www.cirrusinsight.com/blog/101-sales-email-templates-you-can-use-to-close-more-deals"

# %%
response = requests.get(url)

# %%
soup = bs(response.content,'html5lib')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   101 Sales Email Templates You Can Use to Close More Deals\n  </title>\n  <link href="https://www.cirrusinsight.com/hubfs/images/branding/CirrusInsight-Symbol-1x1.png" rel="shortcut icon"/>\n  <meta content="" name="description"/>\n  <meta content="" property="og:description"/>\n  <meta content="101 Sales Email Templates You Can Use to Close More Deals" property="og:title"/>\n  <meta content="" name="twitter:description"/>\n  <meta content="101 Sales Email Templates You Can Use to Close More Deals" name="twitter:title"/>\n  <style>\n   a.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs
# ...

# %%
table = soup.find_all('div',attrs={'class':'ctmpc-ctnts'})

# %%
table[0].find_all('p')
# Out:
# [<p>Hi {name},</p>,
#  <p>My name is {name} with {Your Company}.</p>,
#  <p>We help {specific company type} with {one liner}.</p>,
#  <p>I wanted to learn how you handle {thing your company handles} at {Company Name} and show you what we're working on.</p>,
#  <p>Are you available for a brief call at {time options}.</p>]
